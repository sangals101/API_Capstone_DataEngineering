# %%
# !pip install pymongo
# Out:
# ...
#      |████████████████████████████████| 399kB 1.5MB/s eta 0:00:01
# ...

# %%
from pymongo import MongoClient
from PIL import Image
import io
import os

client = MongoClient("mongodb://API_team:Gl_API#@cluster0-shard-00-00.7rtxo.mongodb.net:27017,cluster0-shard-00-01.7rtxo.mongodb.net:27017,cluster0-shard-00-02.7rtxo.mongodb.net:27017/?ssl=true&replicaSet=atlas-3ndve6-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.chest_xrays
images = db.pneumonia
img_path="/Users/moni/Documents/pneumonia4/"


for image_to_load in os.listdir(img_path):
    fullpath = os.path.join(img_path, image_to_load)
    im = Image.open(fullpath)
    image_bytes = io.BytesIO()
    im.save(image_bytes, format='JPEG')

    image = {
        'data': image_bytes.getvalue(),
        'filename':image_to_load
    }

    image_id = images.insert_one(image).inserted_id
    print(image_id)
    print(image_to_load)
# Out:
# 62af021254091e5445b85446
# person1438_bacteria_3721.jpeg
# 62af021354091e5445b85447
# person1353_virus_2333.jpeg
# 62af021354091e5445b85448
# person1619_bacteria_4261.jpeg
# 62af021354091e5445b85449
# person1514_bacteria_3964.jpeg
# 62af021354091e5445b8544a
# person1491_bacteria_3893.jpeg
# 62af021454091e5445b8544b
# person1598_bacteria_4197.jpeg
# 62af021454091e5445b8544c
# person1816_bacteria_4674.jpeg
# 62af021554091e5445b8544d
# person1812_bacteria_4667.jpeg
# 62af021554091e5445b8544e
# person1415_bacteria_3629.jpeg
# 62af021554091e5445b8544f
# person1372_bacteria_3500.jpeg
# 62af021554091e5445b85450
# person1431_bacteria_3698.jpeg
# 62af021554091e5445b85451
# person1395_virus_2398.jpeg
# 62af021554091e5445b85452
# person1600_virus_2777.jpeg
# 62af021554091e5445b85453
# person1363_virus_2346.jpeg
# 62af021554091e5445b85454
# person1735_bacteria_4570.jpeg
# 62af021554091e5445b85455
# person1731_bacteria_4563.jpeg
# 62af021554091e5445b85456
# person1510_virus_2629.jpeg
# ...

# %%
#storing normal images without pneumonia
db = client.chest_xrays
images = db.normal
img_path="/Users/moni/Documents/normal/"


for image_to_load in os.listdir(img_path):
    fullpath = os.path.join(img_path, image_to_load)
    im = Image.open(fullpath)
    image_bytes = io.BytesIO()
    im.save(image_bytes, format='JPEG')

    image = {
        'data': image_bytes.getvalue(),
        'filename':image_to_load
    }

    image_id = images.insert_one(image).inserted_id
    print(image_id)
    print(image_to_load)
# Out:
# 62af038a54091e5445b857b1
# NORMAL2-IM-0927-0001.jpeg
# 62af038a54091e5445b857b2
# NORMAL2-IM-1056-0001.jpeg
# 62af038a54091e5445b857b3
# IM-0427-0001.jpeg
# 62af038a54091e5445b857b4
# NORMAL2-IM-1260-0001.jpeg
# 62af038a54091e5445b857b5
# IM-0656-0001-0001.jpeg
# 62af038b54091e5445b857b6
# IM-0561-0001.jpeg
# 62af038b54091e5445b857b7
# NORMAL2-IM-1110-0001.jpeg
# 62af038b54091e5445b857b8
# IM-0757-0001.jpeg
# 62af038b54091e5445b857b9
# NORMAL2-IM-1326-0001.jpeg
# 62af038b54091e5445b857ba
# NORMAL2-IM-0736-0001.jpeg
# 62af038b54091e5445b857bb
# NORMAL2-IM-0500-0001.jpeg
# 62af038b54091e5445b857bc
# NORMAL2-IM-0393-0001.jpeg
# 62af038b54091e5445b857bd
# NORMAL2-IM-0994-0001.jpeg
# 62af038b54091e5445b857be
# IM-0207-0001.jpeg
# 62af038c54091e5445b857bf
# IM-0494-0001.jpeg
# 62af038c54091e5445b857c0
# IM-0177-0001.jpeg
# 62af038c54091e5445b857c1
# IM-0388-0001.jpeg
# 62af038c54091e5445b857c2
# IM-0341-0001.jpeg
# 62af038c54091e5445b857c3
# IM-0355-0001.jpeg
# 62af038c54091e5445b857c4
# ...

# %%
#Retrieving images to check

from pymongo import MongoClient
from bson.binary import Binary
from PIL import Image
import io
import matplotlib.pyplot as plt

client = MongoClient("mongodb://API_team:Gl_API#@cluster0-shard-00-00.7rtxo.mongodb.net:27017,cluster0-shard-00-01.7rtxo.mongodb.net:27017,cluster0-shard-00-02.7rtxo.mongodb.net:27017/?ssl=true&replicaSet=atlas-3ndve6-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.chest_xrays
images = db.pneumonia
image = images.find_one()

pil_img = Image.open(io.BytesIO(image['data']))
plt.imshow(pil_img)
